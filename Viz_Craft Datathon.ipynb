# %%
# Importing required libraries for assignment 
import os
import pandas as pd
import numpy as np
from statsmodels.imputation import mice
import statsmodels.api as sm
from sklearn import linear_model
import matplotlib.pyplot as plt
import statsmodels.api as sm
import sklearn.preprocessing as prep
from sklearn.decomposition import PCA
from numpy.linalg import eigh
import os
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
os.chdir(r'/Users/mohnish/Desktop/VizCraft')

# %%
# Reading the dataset from my location 
Demo_data = pd.read_csv(r'Demographic_Data.csv')
Demo_data
# Out:
#         REF ID     MEMBER ID  MEMBER_AGE MEMBER_GENDER STATE SOLD  \
# 0        39584   CA-C38518-1          69             M         CA
# 1        39585   CA-C38519-1          29             M         CA
# 2        39586   CA-C38520-1          51             M         CA
# 3        39587   CA-C38521-1          52             F         CA
# 4        39588   CA-C38522-1          63             F         CA
# ...        ...           ...         ...           ...        ...
# 332370  287009  VA-C272303-1          41             M         VA
# 332371  287010  VA-C272304-1          63             M         VA
# 332372  287011  VA-C272305-1          50             M         VA
# 332373  287012  VA-C272306-1          52             M         VA
# 332374  287013  VA-C272307-1          31             F         VA
#
#                 COUNTY  ZIPCODE LOB REFERRAL_TYPE            MEMBER_LANGUAGE
# 0            SAN DIEGO  92101.0   C             M          English (Default)
# ...

# %%
# Define a function to categorize age groups

# Define a mapping dictionary for categories to new values
mapping = {'1': other, '2': other, 'U': other}

# Create a new variable based on categories of the existing variable
Demo_data['GENDER'] = Demo_data['MEMBER_GENDER'].map(mapping)

# Print the DataFrame with the new variable
print(Demo_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 # Define a function to categorize age groups
#       2
#       3 # Define a mapping dictionary for categories to new values
# ----> 4 mapping = {'1': other, '2': other, 'U': other}
#       6 # Create a new variable based on categories of the existing variable
#       7 Demo_data['GENDER'] = Demo_data['MEMBER_GENDER'].map(mapping)
#
# NameError: name 'other' is not defined

# %%
# Create a new column based on the 'Age' column
Demo_data['GENDER'] = Demo_data['MEMBER_GENDER'].apply(categorize_gender)

print(df)

# %%
# Reading the dataset from my location 
CDD = pd.read_csv(r'Cleaned_Demographic_Data.csv')
CDD.rename(columns={'REF ID': 'REFERRAL_ID'}, inplace=True)
CDD
# Out:
#         REFERRAL_ID     MEMBER ID  MEMBER_AGE MEMBER_GENDER STATE SOLD  \
# 0             39584   CA-C38518-1          69             M         CA
# 1             39585   CA-C38519-1          29             M         CA
# 2             39586   CA-C38520-1          51             M         CA
# 3             39587   CA-C38521-1          52             F         CA
# 4             39588   CA-C38522-1          63             F         CA
# ...             ...           ...         ...           ...        ...
# 332370       287009  VA-C272303-1          41             M         VA
# 332371       287010  VA-C272304-1          63             M         VA
# 332372       287011  VA-C272305-1          50             M         VA
# 332373       287012  VA-C272306-1          52             M         VA
# 332374       287013  VA-C272307-1          31             F         VA
#
#                 COUNTY  ZIPCODE LOB REFERRAL_TYPE            MEMBER_LANGUAGE
# ...

# %%
Call_log =pd.read_csv(r'Hackathon_Call_Log_Data.csv')
Call_log
# Out:
# /var/folders/51/pbr7plsj5pb0mpycpxm6txjh0000gn/T/ipykernel_90510/3282495950.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   Call_log =pd.read_csv(r'Hackathon_Call_Log_Data.csv')
#              CALL ID                  TIMESTAMP CALL TYPE  \
# 0       1.431070e+05   Thu, 1 Jun 2023 13:38:33   Inbound
# 1       1.439220e+05   Thu, 1 Jun 2023 15:58:11   Inbound
# 2       1.440270e+05   Thu, 1 Jun 2023 16:16:58   Inbound
# 3       1.440300e+05   Thu, 1 Jun 2023 16:17:42   Inbound
# 4       1.441790e+05   Thu, 1 Jun 2023 16:35:34   Inbound
# ...              ...                        ...       ...
# 885980  3.000000e+14  Sat, 27 Jan 2024 14:19:18  Outbound
# 885981  3.000000e+14  Sat, 27 Jan 2024 14:19:48  Outbound
# 885982  3.000000e+14  Sat, 27 Jan 2024 14:20:18  Outbound
# 885983  3.000000e+14  Sat, 27 Jan 2024 14:20:36  Outbound
# 885984  3.000000e+14  Sat, 27 Jan 2024 14:20:58  Outbound
#
# ...

# %%
# Perform a left join
result_df = pd.merge(CDD, Call_log, on='REFERRAL_ID', how='outer')
result_df
# Out:
#         REFERRAL_ID    MEMBER ID  MEMBER_AGE MEMBER_GENDER STATE SOLD  \
# 0           39584.0  CA-C38518-1        69.0             M         CA
# 1           39584.0  CA-C38518-1        69.0             M         CA
# 2           39585.0  CA-C38519-1        29.0             M         CA
# 3           39585.0  CA-C38519-1        29.0             M         CA
# 4           39585.0  CA-C38519-1        29.0             M         CA
# ...             ...          ...         ...           ...        ...
# 967770     344219.0          NaN         NaN           NaN        NaN
# 967771     344222.0          NaN         NaN           NaN        NaN
# 967772     344233.0          NaN         NaN           NaN        NaN
# 967773     344235.0          NaN         NaN           NaN        NaN
# 967774     344189.0          NaN         NaN           NaN        NaN
#
#            COUNTY  ZIPCODE  LOB REFERRAL_TYPE    MEMBER_LANGUAGE  ...  \
# ...

# %%
# Remove rows with NA in variable 'A'
df_cleaned = result_df.dropna(subset=['REFERRAL_ID'])

# Print the cleaned DataFrame
df_cleaned
# Out:
#         REFERRAL_ID    MEMBER ID  MEMBER_AGE MEMBER_GENDER STATE SOLD  \
# 0           39584.0  CA-C38518-1        69.0             M         CA
# 1           39584.0  CA-C38518-1        69.0             M         CA
# 2           39585.0  CA-C38519-1        29.0             M         CA
# 3           39585.0  CA-C38519-1        29.0             M         CA
# 4           39585.0  CA-C38519-1        29.0             M         CA
# ...             ...          ...         ...           ...        ...
# 967770     344219.0          NaN         NaN           NaN        NaN
# 967771     344222.0          NaN         NaN           NaN        NaN
# 967772     344233.0          NaN         NaN           NaN        NaN
# 967773     344235.0          NaN         NaN           NaN        NaN
# 967774     344189.0          NaN         NaN           NaN        NaN
#
#            COUNTY  ZIPCODE  LOB REFERRAL_TYPE    MEMBER_LANGUAGE  ...  \
# ...

# %%
duplicate_counts = df_cleaned['REFERRAL_ID'].value_counts()
duplicate_counts
# Out:
# Empty DataFrame
# Columns: [REFERRAL_ID, MEMBER ID, MEMBER_AGE, MEMBER_GENDER, STATE SOLD, COUNTY, ZIPCODE, LOB, REFERRAL_TYPE, MEMBER_LANGUAGE, CALL ID, TIMESTAMP, CALL TYPE, DISPOSITION, TALK TIME, AFTER CALL WORK TIME, DAY OF MONTH, HOUR OF DAY, DAY OF WEEK, MONTH, CONTACTED, HANDLE TIME, Referral_Code, State -  LOB, Referral Date, HALF HOUR, DATE]
# Index: []
#
# [0 rows x 27 columns]

# %%
total_duplicate_count = len(df_cleaned) - len(df_cleaned['REFERRAL_ID'].drop_duplicates())
total_duplicate_count
# Out:
# 573268

# %%
df_cleaned.to_csv('Final_data_1.csv', index=False)

# %%
# Removing 'NA' values from the age. bacause we cannot infer anything based on call log data 

df_cleaned_1 = df_cleaned.dropna(subset=['MEMBER_AGE'])

df_cleaned_1
# Out:
#         REFERRAL_ID     MEMBER ID  MEMBER_AGE MEMBER_GENDER STATE SOLD  \
# 0           39584.0   CA-C38518-1        69.0             M         CA
# 1           39584.0   CA-C38518-1        69.0             M         CA
# 2           39585.0   CA-C38519-1        29.0             M         CA
# 3           39585.0   CA-C38519-1        29.0             M         CA
# 4           39585.0   CA-C38519-1        29.0             M         CA
# ...             ...           ...         ...           ...        ...
# 904149     287012.0  VA-C272306-1        52.0             M         VA
# 904150     287012.0  VA-C272306-1        52.0             M         VA
# 904151     287013.0  VA-C272307-1        31.0             F         VA
# 904152     287013.0  VA-C272307-1        31.0             F         VA
# 904153     287013.0  VA-C272307-1        31.0             F         VA
#
#            COUNTY  ZIPCODE LOB REFERRAL_TYPE            MEMBER_LANGUAGE  ...  \
# ...

# %%
df_cleaned_2 = df_cleaned_1.dropna(subset=['CALL ID'])

df_cleaned_2
# Out:
#         REFERRAL_ID     MEMBER ID  MEMBER_AGE MEMBER_GENDER STATE SOLD  \
# 0           39584.0   CA-C38518-1        69.0             M         CA
# 1           39584.0   CA-C38518-1        69.0             M         CA
# 2           39585.0   CA-C38519-1        29.0             M         CA
# 3           39585.0   CA-C38519-1        29.0             M         CA
# 4           39585.0   CA-C38519-1        29.0             M         CA
# ...             ...           ...         ...           ...        ...
# 904149     287012.0  VA-C272306-1        52.0             M         VA
# 904150     287012.0  VA-C272306-1        52.0             M         VA
# 904151     287013.0  VA-C272307-1        31.0             F         VA
# 904152     287013.0  VA-C272307-1        31.0             F         VA
# 904153     287013.0  VA-C272307-1        31.0             F         VA
#
#            COUNTY  ZIPCODE LOB REFERRAL_TYPE            MEMBER_LANGUAGE  ...  \
# ...

# %%
df_cleaned_2.to_csv('Final_data_2.csv', index=False)

# %%
import pandas as pd


# Define a custom function to create a new variable based on categories
def create_new_variable(category):
    if category == 'A':
        return 'Category_A'
    elif category == 'B':
        return 'Category_B'
    elif category == 'C':
        return 'Category_C'
    else:
        return 'Unknown_Category'

# Create a new variable based on different categories of 'Category'
df['New_Category'] = df['Category'].apply(create_new_variable)

# Print the DataFrame with the new variable
print(df)

# %%
# Uploading Final Data

Final_data = pd.read_csv(r'Final_data_2.csv')
Final_data
# Out:
# /var/folders/51/pbr7plsj5pb0mpycpxm6txjh0000gn/T/ipykernel_90510/1556427768.py:3: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   Final_data = pd.read_csv(r'Final_data_2.csv')
#         REFERRAL_ID     MEMBER ID  MEMBER_AGE MEMBER_GENDER STATE SOLD  \
# 0             39584   CA-C38518-1          69             M         CA
# 1             39584   CA-C38518-1          69             M         CA
# 2             39585   CA-C38519-1          29             M         CA
# 3             39585   CA-C38519-1          29             M         CA
# 4             39585   CA-C38519-1          29             M         CA
# ...             ...           ...         ...           ...        ...
# 822359       287012  VA-C272306-1          52             M         VA
# 822360       287012  VA-C272306-1          52             M         VA
# 822361       287013  VA-C272307-1          31             F         VA
# ...

# %%
df_encoded = pd.get_dummies(Final_data, columns=['MEMBER_GENDER'], prefix='MEMBER_GENDER')
df_encoded
# Out:
#         REFERRAL_ID     MEMBER ID  MEMBER_AGE STATE SOLD     COUNTY  ZIPCODE  \
# 0             39584   CA-C38518-1          69         CA  SAN DIEGO    92101
# 1             39584   CA-C38518-1          69         CA  SAN DIEGO    92101
# 2             39585   CA-C38519-1          29         CA     PLACER    95603
# 3             39585   CA-C38519-1          29         CA     PLACER    95603
# 4             39585   CA-C38519-1          29         CA     PLACER    95603
# ...             ...           ...         ...        ...        ...      ...
# 822359       287012  VA-C272306-1          52         VA     LOUISA    23024
# 822360       287012  VA-C272306-1          52         VA     LOUISA    23024
# 822361       287013  VA-C272307-1          31         VA   TAZEWELL    24637
# 822362       287013  VA-C272307-1          31         VA   TAZEWELL    24637
# 822363       287013  VA-C272307-1          31         VA   TAZEWELL    24637
#
# ...

# %%
df_encoded_1 = pd.get_dummies(df_encoded, columns=['LOB'], prefix='LOB')
df_encoded_1
# Out:
#         REFERRAL_ID     MEMBER ID  MEMBER_AGE STATE SOLD     COUNTY  ZIPCODE  \
# 0             39584   CA-C38518-1          69         CA  SAN DIEGO    92101
# 1             39584   CA-C38518-1          69         CA  SAN DIEGO    92101
# 2             39585   CA-C38519-1          29         CA     PLACER    95603
# 3             39585   CA-C38519-1          29         CA     PLACER    95603
# 4             39585   CA-C38519-1          29         CA     PLACER    95603
# ...             ...           ...         ...        ...        ...      ...
# 822359       287012  VA-C272306-1          52         VA     LOUISA    23024
# 822360       287012  VA-C272306-1          52         VA     LOUISA    23024
# 822361       287013  VA-C272307-1          31         VA   TAZEWELL    24637
# 822362       287013  VA-C272307-1          31         VA   TAZEWELL    24637
# 822363       287013  VA-C272307-1          31         VA   TAZEWELL    24637
#
# ...

# %%
df_encoded_2 = pd.get_dummies(df_encoded_1, columns=['CALL TYPE','DAY OF WEEK','MONTH'], prefix=['CALL TYPE','DAY OF WEEK','MONTH'])
df_encoded_2
# Out:
#         REFERRAL_ID     MEMBER ID  MEMBER_AGE STATE SOLD     COUNTY  ZIPCODE  \
# 0             39584   CA-C38518-1          69         CA  SAN DIEGO    92101
# 1             39584   CA-C38518-1          69         CA  SAN DIEGO    92101
# 2             39585   CA-C38519-1          29         CA     PLACER    95603
# 3             39585   CA-C38519-1          29         CA     PLACER    95603
# 4             39585   CA-C38519-1          29         CA     PLACER    95603
# ...             ...           ...         ...        ...        ...      ...
# 822359       287012  VA-C272306-1          52         VA     LOUISA    23024
# 822360       287012  VA-C272306-1          52         VA     LOUISA    23024
# 822361       287013  VA-C272307-1          31         VA   TAZEWELL    24637
# 822362       287013  VA-C272307-1          31         VA   TAZEWELL    24637
# 822363       287013  VA-C272307-1          31         VA   TAZEWELL    24637
#
# ...

# %%
variable_names = df_encoded_2.columns.tolist()
print(variable_names)
# Out:
# ['REFERRAL_ID', 'MEMBER ID', 'MEMBER_AGE', 'STATE SOLD', 'COUNTY', 'ZIPCODE', 'REFERRAL_TYPE', 'MEMBER_LANGUAGE', 'CALL ID', 'TIMESTAMP', 'DISPOSITION', 'Success_contact', 'Actual_contact', 'TALK TIME', 'AFTER CALL WORK TIME', 'DAY OF MONTH', 'HOUR OF DAY', 'CONTACTED', 'HANDLE TIME', 'Referral_Code', 'State -  LOB', 'Referral Date', 'HALF HOUR', 'DATE', 'MEMBER_GENDER_F', 'MEMBER_GENDER_M', 'MEMBER_GENDER_U', 'LOB_C', 'LOB_D', 'LOB_M', 'CALL TYPE_3rd party conference', 'CALL TYPE_3rd party transfer', 'CALL TYPE_Inbound', 'CALL TYPE_Inbound Voicemail', 'CALL TYPE_Manual', 'CALL TYPE_Outbound', 'CALL TYPE_Outbound Voicemail', 'CALL TYPE_Queue Callback', 'DAY OF WEEK_Friday', 'DAY OF WEEK_Monday', 'DAY OF WEEK_Saturday', 'DAY OF WEEK_Sunday', 'DAY OF WEEK_Thursday', 'DAY OF WEEK_Tuesday', 'DAY OF WEEK_Wednesday', 'MONTH_August', 'MONTH_December', 'MONTH_January', 'MONTH_July', 'MONTH_June', 'MONTH_November', 'MONTH_October', 'MONTH_September']

# %%
# Separate features and target variable
X = df_encoded_2[['MEMBER_AGE','MEMBER_GENDER_F', 'MEMBER_GENDER_M', 'MEMBER_GENDER_U', 'LOB_C', 'LOB_D', 'LOB_M', 'DAY OF WEEK_Friday', 'DAY OF WEEK_Monday', 'DAY OF WEEK_Saturday', 'DAY OF WEEK_Sunday', 'DAY OF WEEK_Thursday', 'DAY OF WEEK_Tuesday', 'DAY OF WEEK_Wednesday','HOUR OF DAY','DAY OF MONTH',]]
y = df_encoded_2['Actual_contact']

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt


clf = DecisionTreeClassifier()
clf.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
# Visualize the decision tree

tree.plot_tree(clf, feature_names=X.columns, class_names=['0', '1'], filled=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[62], line 3
#       1 # Visualize the decision tree
# ----> 3 tree.plot_tree(clf, feature_names=X.columns, class_names=['0', '1'], filled=True)
#       4 plt.show()
#
# File ~/New_anaconda/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:201, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     198 to_ignore += ["self", "cls"]
#     199 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 201 validate_parameter_constraints(
#     202     parameter_constraints, params, caller_name=func.__qualname__
#     203 )
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
#
# ...

# %%
# Show segments based on the tree's splits
segments = clf.apply(X)
print("Segments based on the decision tree's splits:")
print(segments)
# Out:
# Segments based on the decision tree's splits:
# [206296 207211 181971 ...  58631  65063 122344]

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_text
tree_rules = export_text(clf, feature_names=list(X.columns))
print(tree_rules)
# Out:
# |--- LOB_M <= 0.50
# |   |--- HOUR OF DAY <= 14.50
# |   |   |--- LOB_C <= 0.50
# |   |   |   |--- MEMBER_AGE <= 71.50
# |   |   |   |   |--- MEMBER_AGE <= 58.50
# |   |   |   |   |   |--- MEMBER_AGE <= 29.00
# |   |   |   |   |   |   |--- DAY OF WEEK_Wednesday <= 0.50
# |   |   |   |   |   |   |   |--- class: Negative_contact
# |   |   |   |   |   |   |--- DAY OF WEEK_Wednesday >  0.50
# |   |   |   |   |   |   |   |--- class: Not_contacted
# |   |   |   |   |   |--- MEMBER_AGE >  29.00
# |   |   |   |   |   |   |--- DAY OF MONTH <= 3.50
# |   |   |   |   |   |   |   |--- MEMBER_GENDER_U <= 0.50
# |   |   |   |   |   |   |   |   |--- HOUR OF DAY <= 12.50
# |   |   |   |   |   |   |   |   |   |--- DAY OF MONTH <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Negative_contact
# |   |   |   |   |   |   |   |   |   |--- DAY OF MONTH >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Not_contacted
# |   |   |   |   |   |   |   |   |--- HOUR OF DAY >  12.50
# ...

# %%
plt.figure(figsize=(12, 8))
tree.plot_tree(clf, filled=True, feature_names=X.feature_names, class_names=Y.target_names)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/51/pbr7plsj5pb0mpycpxm6txjh0000gn/T/ipykernel_90510/2541258630.py in ?()
#       1 plt.figure(figsize=(12, 8))
# ----> 2 tree.plot_tree(clf, filled=True, feature_names=X.feature_names, class_names=Y.target_names)
#       3 plt.show()
#
# ~/New_anaconda/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'feature_names'
